# %%
# %%HTML
# <style>
#     body {
#         --vscode-font-family: "Vollkorn"
#     }
# </style>
# Out:
# <style>
#     body {
#         --vscode-font-family: "Vollkorn"
#     }
# </style>

# %%
from pathlib import Path
import shutil
import requests
from datetime import datetime, date

from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import ee
import geemap.foliumap as geemap
import geedim as gd

import fiona as fio
import rasterio as rio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 12
#       9 import pandas as pd
#      10 import matplotlib.pyplot as plt
# ---> 12 import ee
#      13 import geemap.foliumap as geemap
#      14 import geedim as gd
#
# ModuleNotFoundError: No module named 'ee'

# %%
#ee.Authenticate()
ee.Initialize()

# %%
start_date = date(2010, 1, 1)
end_date = date(2010, 2, 1)

# %%
hs_collection = gd.MaskedCollection.from_name("EO1/HYPERION")
hs_collection = hs_collection.search(str(start_date), str(end_date))
# Out:
# Specifying `start_date` and `region` will improve the search speed.

# %%
print(hs_collection.schema_table)
print(hs_collection.properties_table)
# Out:
# ABBREV  NAME               DESCRIPTION
# ------  -----------------  -------------------------------------------
# ID      system:id          Earth Engine image id
# DATE    system:time_start  Image capture date/time (UTC)
# FILL    FILL_PORTION       Portion of region pixels that are valid (%)
# ID                                         DATE
# ------------------------------------------ ----------------
# EO1/HYPERION/EO1H1090942010001110KF_PF2_01 2010-01-01 01:30
# EO1/HYPERION/EO1H0190332010001110KF_SGS_01 2010-01-01 15:53
# EO1/HYPERION/EO1H0170602010001110T1_SGS_01 2010-01-01 16:03
# EO1/HYPERION/EO1H0330372010001110KA_PF2_01 2010-01-01 17:33
# EO1/HYPERION/EO1H0500742010001110T2_SGS_01 2010-01-01 19:26
# EO1/HYPERION/EO1H0551152010001110KF_SGS_01 2010-01-01 19:43
# EO1/HYPERION/EO1H0660732010001110T2_SGS_01 2010-01-01 21:04
# EO1/HYPERION/EO1H0661352010001110PF_SGS_01 2010-01-01 21:29
# EO1/HYPERION/EO1H0820702010001110TC_PF1_01 2010-01-01 22:42
# ...
